# %% [markdown]
# ## 참고 사이트
#  - https://github.com/jsvine/pdfplumber#python-library

# %%
# %pip install pdfplumber -q
# Out:
# [notice] A new release of pip is available: 23.0.1 -> 23.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install python-docx
# Out:
# Collecting python-docx
#   Using cached python_docx-0.8.11-py3-none-any.whl
# Collecting lxml>=2.3.2
#   Using cached lxml-4.9.2.tar.gz (3.7 MB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: lxml
#   Building wheel for lxml (setup.py) ... done
#   Created wheel for lxml: filename=lxml-4.9.2-cp311-cp311-macosx_13_0_arm64.whl size=1641936 sha256=accac2732806755aaf3afa235fa1ca7bafad4790a042a6d8471c1dd93b429f3b
#   Stored in directory: /Users/hanseungryun/Library/Caches/pip/wheels/fb/5b/f7/0a27880b4a007daeff53a196d01901627f640392b7e76e76e5
# Successfully built lxml
# Installing collected packages: lxml, python-docx
# Successfully installed lxml-4.9.2 python-docx-0.8.11
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pdfplumber as pp

with pp.open('test.pdf') as book :
    for page_no, page in enumerate(book.pages, start=1):
        text = page.extract_text()
        # pdf 파일의 이미지 추출
        images = page.images(0)
        
        # text, images를 파일로 저장
        with open(f'page_{page_no}.word', 'w') as f:
            f.write(text)
            
        print(f'page {page_no}')
        print(text.strip())
        print("-"*50)
# Out:
# page 1
# Analysis and Research Team
# ⸺
# 2023
# 24 April
# ART - RESEARCH PAPER
# ChatGPT in the Public Sector –
# overhyped or overlooked?
# ⸺
# Executive Summary
# The unprecedented success of AI tools If ChatGPT and similar tools become part of daily work-
# like ChatGPT caught many by sur- flows, this trend will also affect public institutions. By pro-
# prise. But large language models (LLM) viding services which are instrumental to the functioning
# are here to stay and will continue to of the State and affecting the rights and obligations of
# grow in sophistication. These models citizens, the public sector is particularly sensitive to the
# use natural language processing algorithms to interpret introduction of such AI-based technologies. Public admi-
# and respond to text-based human input. Whilst it is pos- nistration has its own characteristics and principles which
# sible to grasp the basic principles which drive models distinguish it from the private sector. By extension, the key
# such as ChatGPT, the companies behind them - mostly principles of public administration such as accountability,
# US-based - are becoming increasingly coy about relea- transparency, impartiality, or reliability need to be consi-
# sing detailed information on the code and parameters dered thoroughly in the integration process.
# which determine the way they generate their outputs.
# That makes it more challenging to assess the implica- To benefit from the advantages offered by ChatGPT and
# tions and impact of integrating large language models similar tools, risks should be recognised, managed and,
# into the workplace. At the current rate of expansion, it’s where possible, mitigated. Whilst some of the existing
# only a matter of time before such models are integrated limitations will be addressed by technological advances,
# into the public sector with wide practical applica- others, such as biases, are of a more structural nature
# tions, advantages, and possible efficiency gains, from and cannot be fully corrected. Measures are there-
# 24/7 availability to managing large volumes of inquiries fore needed to ensure that the appropriate procedures
# simultaneously. and human controls are in place as well as the
# establishment of feedback loops from the citizens and
# But there are also limitations. While sophisticated Al such independent audits.
# as ChatGPT may seem extremely intelligent, capable, and
# reliable, this is not a wholly accurate picture. ChatGPT In the absence of clear regulation on ChatGPT accounta-
# certainly has some capabilities at a speed and scale that bility, humans are needed to monitor output especially
# humans do not, but it sometimes provides responses when considering what lies ahead. And only humans
# which are inaccurate, biased, or nonsensical. Its purely can provide the personalised services, flexibility, emotio-
# mathematical approach to reasoning should not be mis- nal intelligence, and critical thinking needed to fulfil the
# taken for human-like intelligence. requirements of public service.
# Disclaimer: The opinions expressed are solely those of the author(s). In no case should they be considered or construed as representing an official position of the Council
# of the European Union or the European Council. © European Union, 2023 Reproduction is authorised provided the source is acknowledged. Any question or comment should
# be addressed to ART@consilium.europa.eu ⸺ 1
# --------------------------------------------------
# page 2
# ⸺ 2
# Introduction
# The release of ChatGPT in November 2022 has look at the technology behind ChatGPT. It also
# prompted a lively debate about its strengths and highlights possible risks and opportunities this
# weaknesses, its potential, possible risks, and its could create for the public sector both now and in
# occasionally bizarre responses. To cut through these the future.
# discussions, it is important to step back and realise
# that large language models (LLMs) such as ChatGPT To improve our understanding of what LLMs like
# have been part of our daily lives for some time: Goo- ChatGPT might mean for the public sector, the paper
# gle searches in English, for example, have been sup- begins by looking at how ChatGPT works, who is
# ported by AI technology since 2019. Yet the practical behind it, and what differentiates it from other
# and political implications of ChatGPT remain difficult language models and chatbots. This leads into an
# to pin down, and it is important to avoid underesti- assessment of the extent to which language models
# mating or overestimating the capabilities of LLMs. could help support the work of public servants, but
# There are also important questions around who is also their potential risks and pitfalls. It then looks at
# developing this technology and where. These issues how these might be mitigated. The paper ends by
# are critical to the process of integrating of LLMs into assessing the future development of LLMs and their
# the workplace, particularly for the public sector. possible implications for the future of the public
# sector.
# This note takes ChatGPT as the basis for assessing
# the impact of increasingly sophisticated language A glossary in the Annex contains explanations of
# models on the public sector and the principles on some of the technical terms that appear throughout
# which it is based. It takes an objective and factual the paper.
# 1. What is ChatGPT
# ChatGPT is a form of Artificial Intelligence which fine-tuned to make them appear to originate from a
# can process and produce natural language, and human source. It is important to remember that it
# which is capable of a large range of text-based tasks. does not have the ability to process and understand
# ChatGPT does not itself understand the meaning meaning in the way humans do1.
# of the text it produces. Its responses are based on
# statistics and probability, but it has been sufficiently
# “
# ChatGPT does not itself understand the
# meaning of the text it produces. Its responses
# How did we get here?
# are based on statistics and probability
# Language has always been at the heart of artificial ”
# intelligence (see fig.1). Ever since AI was conceived in
# a computational context, most notably by Enigma The 21st century has seen exponential growth in the
# codebreaker Alan Turing in the 1950s2, the ‘intel- sophistication of artificial intelligence, especially
# ligence’ of an AI programme has been measured since the rise of ‘Big Data’ in the 2010s. Big Data
# by its ability to imitate human language capabili- refers to extremely large data sets containing diffe-
# ties3. Until the 1980s, the development of language rent types of data which can be analysed computa-
# models (and AI more broadly) aimed at not merely tionally to reveal correlations, patterns, and trends
# imitating human language but actually grasping within a particular population. Coupled with the
# it. In the late 1980s, the approach shifted towards increasing market dominance of US-based major
# probabilistic models, which produced output based tech companies such as Amazon, Apple, Google, and
# on calculations informed by datasets and which led Meta, which collect data through their platforms,
# to the emergence of statistical language models4. these datasets have grown massively, and consti-
# tute an unprecedented resource pool.
# --------------------------------------------------
# page 3
# ⸺ 3
# 1950 However, it was the development of deep learning
# Turing’s Computing techniques5, particularly neural networks and later
# Machinery and Intelligence
# transformers6, that enabled the creation of much
# larger and more sophisticated language models.
# 1960 Logic Theorists The text generated by these models is generally
# invented
# coherent and nuanced, often indistinguishable from
# human writing or speech. This raises ethical ques-
# tions about the conflation of human-based and
# Early work in natural ELIZA
# computer-based communication.
# language processing (NLP) created
# focuses on rule-based 1970
# systems, with researchers
# developing hand-crafted parameter count (in billions)
# grammars and semantic rules
# 1000
# to analyze and generate text. 1st AI
# winter
# 1980
# Expert Systems
# 540BPaLM
# introduced
# 530B
# 280BGopher
# Megatron
# -Turing NLG 176BBLOOM
# Statistical language models,
# 2nd AI 175B
# such as the n-gram model 175BOPT-175b
# and the Hidden Markov 1990 winter GPT-3 137B
# 100 LaMDA
# Model (HMM), begin to
# emerge, using probabilistic
# models to analyze and 70B 65B
# generate natural language. Chinchilla LLaMa
# Deep Blue defeats
# Garry Kasparov
# 2000
# The development of
# neural network-based
# 10
# language models, such
# as the Recurrent Neural
# Network (RNN) and the 2010
# Long Short-Term Memory
# (LSTM) model, allows for
# the creation of larger and Global market for big data
# more sophisticated language reaches $10 billion USD
# models, with millions of
# parameters (see fig.2). likely 2B
# Introduction of
# 2020 Transformer architecture 1.5B Bard/ LaMDA
# 1 GPT-2 lightweight
# The development and
# acceleration of large
# language models (LLMs). 117M
# GPT-2
# Legend
# 345MBERT large
# 110MBERT base
# Progress of LLMs 0.1
# 2018 2019 2020 2021 2022 2023
# AI milestones
# Reduced activity Legend 2022
# ChatGPT: N/A
# or limited progress
# OpenAI BigScience
# in the field of AI 2023
# Google / DeepMind Microsoft / NVIDIA
# Sparrow: N/A
# Meta
# GPT-4: N/A
# Fig. 1: Exponential growth of artificial intelligence
# development Fig. 2: Parameters of selected models in millions (M) or billions (B)
# --------------------------------------------------
# page 4
# ⸺ 4
# How does ChatGPT work?
# ChatGPT is an AI chatbot7 overlaying a Large Lan- each segment for the overall meaning of the input
# guage Model (LLM), a type of machine-learning sequence. During its training, the model uses these
# model designed to process natural language (see values to generate billions of normalised weights
# fig.3). These models are a part of what is called which provide a basis on which it can calculate the
# general purpose AI systems, which can perform a most accurate response to the input it receives.
# range of general tasks such as translating, detecting ChatGPT’s model performs these calculations seve-
# patterns, or answering questions8. LLMs use large ral times in a row, which enables it to recognise
# quantities of text to infer the relationship between more subtextual meanings, such as humour. Howe-
# different words in these texts and use this informa- ver, this also explains why it can end up generating
# tion to generate their own human-like texts. At their different answers to very similar questions: varying
# most basic, LLMs work in a similar way to predictive the position of a word in a sentence triggers a diffe-
# texting on a mobile phone. They determine which rent sequence of calculations, which in turn leads to
# words are statistically likely to appear after each differently worded answers.
# other and use this knowledge to predict the next
# word. LLMs can be classified both by their parameters and
# the amount of data used to train them. Parameters
# However, these simpler models are unable to grasp are the weights and biases the model has learned
# more nuanced connections within the language during its training. They drive its decision-making
# they are processing. When faced with multiple processes, like neurons in a human brain. During
# similar options to generate the next word in a sen- the training phase these parameters are constantly
# tence, they are often unable to choose the most adjusted and updated by a self-learning algorithm
# logically appropriate one9. Models like those used within the model. As a rule of thumb, the more
# by ChatGPT, so-called Transformers, can solve this parameters a model has, the broader the range
# issue with a mechanism called self-attention10. of tasks it can perform11. The more training data it
# Self-attention allows these models to subdivide has been fed, the more precisely it can adjust its
# their input data into small segments (tokens) and weights, and the more accurately it will respond to
# assign them values based on the importance of a user’s query12.
# request chatgpt output
# large language model
# based on transformers
# user extensive context-
# based reply
# transformers
# neural networks that learn context and
# meaning in sequential data by tracking
# relationships between words.
# self attention parameters fine-tuning
# allows the Transformer to attend to all weights and biases the model has adapts the model’s self-learned
# the words when encoding it, as opposed learned during its training driving parameters for specific tasks with
# to just the words that are nearby. its decision-making process. tailored training data.
# Fig.3: Functioning of ChatGPT
# --------------------------------------------------
# page 5
# ⸺ 5
# After some initial training, LLMs are often fine- feedback was used during the fine-tuning process
# tuned to generate responses which are more closely to ensure the output is more closely aligned with the
# aligned to the user’s intent. Fine-tuned models can intentions of the user14.
# be based on larger models with more general capa-
# bilities. For example, the model behind the initial In addition to text-generating models such as
# version of ChatGPT is based on an existing LLM that ChatGPT, there are now also LLMs specialized in
# has been optimised for creating more natural-soun- generating images or even videos from written input.
# ding conversations13. What differentiates ChatGPT Techniques from large language models are also
# from other language models is the way human used to complete and generate spoken sentences15.
# Which companies are behind it?
# ChatGPT was created by a company called OpenAI, generation models DALL-E and DALL-E 2. It also
# an AI research and deployment company (see fig.4). offers an application programming interface (API),
# Founded in 2015 by Sam Altman, Elon Musk16 and which enables paying customers to develop their
# several former researchers from other AI compa- own applications on top of its models and which
# nies (see. fig.5), OpenAI aims to “ensure that artificial provides its own tools20.
# general intelligence (AGI) - by which we mean highly
# autonomous systems that outperform humans Despite its proclaimed intention to develop AI for the
# at most economically valuable work - benefits all benefit of all humanity, OpenAI has become much
# of humanity”17. Initially a non-profit research lab, less transparent in recent years. Since its change of
# OpenAI has since created a business subsidiary18, structure from a non-profit organisation to a com-
# which enabled it to enter an exclusive commer- mercial subsidiary, it is no longer obliged to publish
# cial partnership with Microsoft in 2019, a deal that the salaries of its principal employees21. While GPT-2
# included investment of $1 billion. In January 2023, was open-source and was released with code and
# both companies announced the extension of their model weights22, its successor, GPT-3, and all sub-
# partnership, with Microsoft investing another $10 sequent models have remained proprietary23. This
# billion19. means that little is known about the architecture
# of the model behind the initial version of ChatGPT,
# OpenAI has developed several AI products, most OpenAI’s most successful model to date, and the
# notably its series of generative pre-trained trans- company refuses to publish detailed information
# former language models, GPT-1 -to -4, and several about the code and parameters which underpin the
# other more specialised models such as the image decision-making processes of its recent models.
# What does the competition look like?
# OpenAI is not the only company developing and costly, not many actors can afford to develop them26.
# deploying large language models at scale. In fact, Big tech companies and a few well-funded start-ups
# even though GPT-3, the model on which ChatGPT is therefore dominate the market.
# based, was by far the largest language model when
# released in 2020, it is no longer either the largest or Partly in response to the high costs of running
# the most accurate. The original ChatGPT launched ChatGPT, OpenAI introduced a $20/month subscrip-
# on 30 November 2022 is using a model called tion plan called ChatGPT Plus on 1 February 2023.
# GPT-3.5-turbo, which is an improved version of the Subscribers gain preferential access to ChatGPT as
# original GPT-3 model24. The details of its architecture well as priority access to new developments. On 14
# have not been revealed by OpenAI, but some sources March 2023, OpenAI launched a new, and suppose-
# assume that it may have as few as 20B parameters25. dly much improved model called GPT-4. The release
# was accompanied by detailed documentation on
# Nevertheless, developing a language model like safety-testing GPT-4, but in line with previous
# ChatGPT can be a complex process. Since training releases it did not contain any details on model size
# and running a large language model can be very and training data.
# --------------------------------------------------
# page 6
# ⸺ 6
# OpenAI’s organisational structure
# OpenAI LP
# OpenAI Inc.
# (Limited Partnership)
# (Incorporated)
# Commercial corporation
# Non-profit organisation
# Capped for-profit subsidiary
# Founded in 2015
# company founded in 2019
# as a non-profit research lab
# by OpenAI Inc.
# OpenAI LP is governed and
# managed by OpenAI Inc’s
# Board o f Directors
# governance: OpenAI Inc’s Board of Directors is comprised of:
# OpenAI LP employees non-employees
# → Greg Brockman (Chairman & President) → Adam D’Angelo → Tasha McCauley current investors
# → Sam Altman (CEO) → Reid Hoffman → Helen Toner → Microsoft
# → Ilya Sutskever (Chief Scientist) → Will Hurd → Shivon Zilis → Reid Hoffman Foundation
# → Khosala Ventures
# ChatGPT
# is a product of OpenAI’s research and development
# made possible in part by its partnership with Microsoft
# OpenAI—Microsoft partnership
# The partnership allows OpenAI to leverage Microsoft’s expertise and resources to advance its research,
# while Microsoft gains access to OpenAI’s cutting-edge AI technology to enhance its own products and services.
# Microsoft is a major investor in OpenAI LP.
# supercomputers
# However, OpenAI remains a separate entity from Microsoft.
# → Microsoft is OpenAI’s exclusive cloud
# a total investment of $13 billion provider for all its computing needs.
# → 2019: exclusive commercial partnership, → Microsoft and OpenAI jointly work
# investment of $1 billion.
# on Microsoft’s Azure AI supercomputers.
# → Jan. 2023: new investment of $10 billion.
# Microsoft and OpenAI offer several ai tools
# → api: Azure OpenAI Services combines OpenAI’s API with Microsoft Azure cloud computing
# platform and allows access to GPT-3, DALL-E2 (by invite only) and other OpenAI models.
# → search: Microsoft is integrating GPT-4 into his search engine Bing.
# → other products: Microsoft could include OpenAI language models
# in other applications, such as its Office programmes.
# Note: Both companies can independently commercialise advanced AI technology emerging from their joint research.
# Fig.4: OpenAI’s structure and partnership with Microsoft
# --------------------------------------------------
# page 7
# ⸺ 7
# What makes ChatGPT stand out are the underlying to their AI-applications, mainly out of concern for
# model’s accessibility and training process. The ini- reputational damage should their technology pro-
# tial ChatGPT uses one of the largest LLMs accessible duce offensive or inaccurate responses. However,
# to the public, and the first to be trained by using OpenAI’s unusual strategy of releasing ChatGPT to
# human feedback - all that is needed to use it is a free the public has prompted a race between big tech
# ChatGPT account27. The way the model has been companies on the release of their own AI to a wider
# fine-tuned to enable conversation-like interaction audience32. In February 2023 alone, Microsoft intro-
# and even follow-up questions make it unique so duced an AI-powered Bing search engine,33 Google
# far compared to other LLMs28. This does not mean announced the introduction of its own conversatio-
# that ChatGPT is always accurate: several pre-print nal AI called Bard,34 and Meta released their new LLM
# articles document that even though ChatGPT per- called LLaMa under a non-commercial license35.
# forms very well when carrying out various reasoning
# and dialogue tasks, it struggles with more complex
# reasoning and mathematics29. Even with its elabo- “
# [The LLM ecosystem] is largely dominated
# rate fine-tuning, it still makes up information, and
# by a handful of mostly US-based
# its built-in safety features on undesired content can
# large tech companies and a group
# be circumvented30. Despite these shortcomings,
# ChatGPT has gained rapidly in popularity. Since its of well-funded start-ups
# ”
# launch in November 2022, the number of daily users
# has been rising steadily, with over 40 million daily
# visits by late February31. Overall, while there are a few other players in the
# large language model ecosystem, it is largely domi-
# Until the release of ChatGPT, no other commercial nated by a handful of mostly US-based large tech
# company had granted access on this scale to such companies and a group of well-funded start-ups,
# a versatile and accurate application. Most state- whose employees often move on to create their own
# of-the-art large language models are proprietary start-ups. ChatGPT has attracted the attention of
# with paid access only. This necessarily limits their a wider public thanks to its easily accessible user
# availability. Large established companies have interface and the way it has been fine-tuned to res-
# tended to be reluctant to give free public access pond to queries.
# 4
# OpenAI’s initial financial supporters
# initial corporate investors collectively pledged US$1 billion
# → 1. Amazon Web S ervices (AWS)
# 5
# → 2. Y Combinator (start-up incubator)
# 1
# → 3. Infosys (Indian IT giant)
# initial individual investors 2
# 6
# → 4. Sam ALTMAN (Y Combinator) 7
# 3
# → 5. Elon MUSK ( CEO of Tesla)
# → 6. Peter THIEL (PayPal co-founder)
# → 7. Jessica LIVINGSTON (Y Combinator partner)
# → 8. Reid HOFFMAN ( LinkedIn co-founder) 8
# → 9. Ilya SUTSKEVER (DeepMind)
# 9
# Fig.5: OpenAI’s initial corporate and individual investors
# --------------------------------------------------
# page 8
# ⸺ 8
# What about the EU industry?
# When it comes to large language models, Euro- “
# The US industry is up to two years ahead
# pean companies have struggled to keep up.
# of European and open-source competitors
# To date, all cutting-edge large language models
# have been developed outside the EU36 (see fig. 6). when it comes to LLM capabilities
# ”
# Much of European AI development is supported
# by academia, which can be a disadvantage in a
# field where most cutting-edge developments AI data centre41. LEAM has produced a feasibility
# come from commercial entities (see fig. 7). Accor- study supported by the German government,
# ding to a study by Large European AI Models which estimates that building a supercomputing
# (LEAM), an initiative of national AI associations infrastructure suitable for AI development in Ger-
# across Europe, the US industry is up to two years many will cost €350-400 million42. The European
# ahead of European and open-source competi- High Performance Computing Joint Undertaking
# tors when it comes to LLM capabilities37. LLMs (EuroHPC JU) is a joint initiative between the
# released by EU member states tend to be smaller, Commission, European countries, and private
# less intensively trained models that improve or partners to develop an ecosystem of European
# imitate existing models. BLOOM, an open-source supercomputers43. It is developing eight super-
# LLM developed by a large scientific collective and computers, one of which is currently the third
# trained on a French supercomputer, and Lumi- fastest globally44. The consortium for High-Per-
# nous, the LLM developed by the German start-up formance Language Technologies (HPLT) aims at
# Aleph Alpha, are two notable exceptions38. The developing multilingual training materials and
# main reason for this is the difficulty in accessing train language models that support European
# venture capital, a lack of computational capa- languages45. In addition, the Commission has
# city, and an insufficient pool of available talent39. issued a €20 million tender for Natural Language
# Raising capital is one of the biggest hurdles for Understanding and Interaction in Advanced Lan-
# new market entrants, which puts European com- guage Technologies through the Horizon pro-
# petitors at a significant disadvantage. Another is gramme, to foster a “human-centred and ethi-
# the lack of commercially available supercompu- cal development” of language models46. Finally,
# ters, where European countries rely much more OpenGPT-X, a collaborative project between
# on public initiatives than the US and China40. science, business and technology funded by the
# German government, builds and trains LLMs for
# There are several ongoing initiatives aimed at the EU economy and intends to offer open-source
# improving Europe’s standing on LLM. Aleph versions of its models47.
# Alpha is launching Europe’s fastest commercial
# China 15
# %
# deveL loL pM m ent 73 % US Com em ne tr itc ii ea sl 86 % deE vn et li ot pie ins g 13 % A inc sa td ite um tioic n s
# Other 13 % location LLM
# 1
# %
# Other
# Fig.6: Geographic origin of cutting-edge large language Fig.7: Type of entities at the forefront of cutting-edge large
# models (LLM) language model (LLM) development
# --------------------------------------------------
# page 9
# ⸺ 9
# 2. What would be the impact of using
# language models in the public sector?
# The nature of work is having to adapt rapidly to the providing services which support the functioning of
# increased use of artificial intelligence. LLMs already the state, and which affect the rights and obligations
# facilitate automated customer service, online of individual citizens, means that it is particularly
# translation, and automatic data analysis, allowing sensitive to the introduction of new technologies
# businesses to reduce staffing levels and save costs. based on AI. There are a range of potential use cases
# But the public sector has a rather different set of of LLMs for the work of public servants, but they
# priorities based on the principle of serving the public could also affect the main principles which underpin
# interest and needs to respect higher standards the work of the public sector.
# of accountability. The role of the public sector in
# How could LLMs support the work of public servants?
# this transition48. More recently, research by Goldman
# “ Sachs estimate that 300 million full-time jobs could
# The fact that LLMs have capabilities beyond
# be affected49.
# that of humans does not necessarily mean
# that all (or any) jobs will disappear
# ” One potential application of LLMs in the public
# sector concerns chatbots and virtual assistants50.
# The fact that LLMs have capabilities beyond that of These models can be used 24/7 to provide a fast and
# humans does not necessarily mean that all (or any) efficient customer service, answer questions and
# jobs will disappear. The dichotomy of replacing jobs address basic issues without the need for human
# through digitalisation as opposed to preserving jobs intervention. This can help free up civil servants'
# at the cost of efficiency is not quite as polarised as time, allowing them to focus on more complex and
# it appears. It is important to distinguish between high-priority tasks. Another area where LLMs could
# the use of LLMs for specific and limited tasks, and be applied in public administration is in document
# its potential to replace entire jobs. A task-oriented or text analysis. An LLM could be trained to iden-
# approach to LLMs in public administration could tify key information in complex documents such as
# enable employees to spend less time working on legal contracts, reducing the time needed for them
# mundane tasks. The time saved could be used to to be reviewed by civil servants. Large language
# bring a more human perspective to their work by models could also be used in decision-making
# allowing more time and energy to be devoted to processes, such as evaluating grant applications
# more interesting tasks or exploring alternative or determining eligibility for social services. By
# approaches to their work. processing and analysing substantial amounts of
# data quickly and accurately, LLMs have the poten-
# One of the key advantages of large language models tial to support fairer and quicker decision-making.
# is their ability to process and analyse large volumes However, LLMs still lack a nuanced understanding of
# of data more quickly and efficiently than humans. human emotions, intentions, and context, which is
# Machinery at this level of sophistication requires why some degree of human supervision will remain
# human oversight and maintenance, which means necessary.
# jobs. Skilled workers in areas such as data analysis,
# cybersecurity, and technology may be able to use LLMs such as ChatGPT can be trained on financial
# LLMs to take over certain tasks, but at the same time and accounting data to provide insights, answer
# there will be a need for workers to take on new tasks questions, generate reports, and provide financial
# and responsibilities. A 2020 World Economic Forum advice based on market trends and data analysis.
# report predicts that by 2025, 85 million jobs will be In the field of human resources, LLMs can assist
# affected (but not necessarily replaced) by machines, with tasks such as the screening of CVs, candi-
# but 97 million new jobs could emerge as a part of date matching, and conducting initial interviews.
# --------------------------------------------------
# page 10
# ⸺ 10
# It is technically possible to train LLMs to conduct In the legal sector, LLMs could be used to analyse and
# automated screening of CVs and recommend the summarise large volumes of legal texts in order to
# best-qualified candidates. They can analyse large support lawyers in the public sector. They could be
# volumes of text-based data such as job descriptions trained to answer legal questions and provide legal
# and CVs to identify patterns and make predictions advice, although this would require close attention
# based on past hiring decisions. Crucially, the quality to ethical and legal principles. In the longer term the
# of the recommendations would depend heavily on use of LLMs could lead to a loss of knowledge and
# the quality and quantity of the initial dataset, and it skills amongst legal professionals. However, it is also
# may not capture crucial factors such as non-verbal possible that large language models could be used
# communication skills, attitudes to work ethics, and to support the work of human lawyers, allowing
# cultural background, as the LLM may not have been them to focus on more complex and nuanced legal
# trained on a sufficiently wide range of data to cap- issues.
# ture these nuances. This means that relying solely
# on an AI-based system for recruitment may lead to
# bias and discrimination, and as such raises some
# ethical concerns.
# How could LLMs affect the main principles of public administrations?
# The public sector has specific characteristics and is impossible to understand why they came to a
# based on a number of principles which distinguish particular result.54 For sensitive decisions by
# it in many ways from the private sector. There are public administrations such as those related to the
# very wide practical applications, advantages, and attribution of social benefits, this raises criti-
# possible efficiency gains in integrating a tool such cal issues around the area of accountability.55
# as ChatGPT within a public administration. Howe-
# ver, the accompanying risks should be recognised,
# managed and, where possible, mitigated. The next → Equality and impartiality
# section of this paper assesses the impact of the pos- are about providing the same treatment to diffe-
# sible introduction of LLMs such as ChatGPT in the rent groups of people to the same standard, irres-
# public sector against each of the eight European pective of their background.
# principles of public administration which are
# inspired by the standards set by the EU/OECD51 for ChatGPT and GPT-4, like AI in general, are subject
# EU candidate countries: to biases56 and discrimination, despite efforts by
# OpenAI to reduce this. Biases are not necessarily
# → Transparency and accountability: negative. They can for example be used to tailor
# accountability is about an administration services to specific skillsets and target audiences,
# acknowledging and assuming responsibility for or to protect the rights of minorities. On the other
# its actions and being able to provide satisfactory hand, biases can undermine the ability of public
# reasons to justify them. Transparency52 facilitates administrations to act impartially. Human agency
# scrutiny and accountability. in public administrations is never entirely free from
# bias, as shown by numerous studies. And according
# These may be more challenging if LLMs are inte- to a recent Eurobarometer poll, 74% of EU citizens
# grated within administrative procedures. Like many also believe that there is corruption in national
# other forms of AI, LLMs are essentially ‘black boxes’, public institutions in their country.57 LLMs could in
# which means that the source code of most models theory help address ingrained bias within a public
# is proprietary and, in any case, confusingly complex. administration.58 But even then, decisions would
# Tech companies have for years used the commer- not be completely unbiased. Most of the biases pre-
# cial interest argument to resist giving access to their sent in LLMs originate from their training datasets,
# algorithms,53 but even those behind these models do which are often based on specific sub-sections of
# not fully understand their creations. Since LLMs train the internet, such as content from Reddit or Wikipe-
# themselves autonomously on their datasets, dia.59 English language data dominates most data-
# and do not explain their reasoning, it is almost sets, while smaller languages are systematically
# --------------------------------------------------
# page 11
# ⸺ 11
# underrepresented.60 Because of this dominance, the → Efficiency:
# values that determine a model’s reasoning are prima- is about making the most effective use of
# rily based on those of a certain segment of US society. resources to deliver substantive outcomes.
# Because of the way they process input, self-taught
# language models can mirror and even amplify LLMs already outperform humans on many
# biases in the data.61 Recent attempts to curate data- more basic administrative tasks. However, these
# sets and fine-tune models during training have efficiency gains come at high cost: language
# reportedly led to some improvements. But the models like ChatGPT require huge computational
# criteria used to filter datasets themselves reflect power for both training and operating66. This is not
# the cultural biases of the curators, who in turn only costly but brings a heavy CO footprint. For
# 2
# represent only a small sub-set of the population.62 example, it is estimated that training GPT-3, the
# So, whilst fine-tuning models like ChatGPT can parent model of ChatGPT, has already generated
# help, it is no silver bullet. Context and perso- around 550t CO 67, which does not yet include the
# 2
# nal preferences can also play a significant role in cost of actually running the model. For the time
# determining whether an individual finds an answer being there are few incentives for model crea-
# acceptable or harmful63. This is also an issue when tors to consider the environmental impact of their
# decision-making in a public administration com- models. Data on computational resources and CO
# 2
# bines human and AI input, with research indicating footprint relative to the model’s capacity are not
# that humans tend to follow AI-generated advice usually published, and the choice of hardware is
# more often when it confirms their pre-existing determined more by computational abilities than
# biases64. In general AI tends to amplify existing emissions and energy use68. Some of the footprint of
# power dynamics65. Issues of equality and impar- LLMs could be mitigated in future through evolving
# tiality therefore arise from a fundamental struc- technology, carbon offsets, or the use of smaller
# tural problem linked to the fact that databases models, which are much cheaper to run and train69.
# and those who program them tend to reflect and But for now, the race has been mostly focused on
# confirm the current dominant worldview. producing the best and most powerful language
# model.
# --------------------------------------------------
# page 12
# ⸺ 12
# → Quality of output: → Predictability and reliability:
# guaranteeing quality of output is important for generating trust by behaving consistently with
# the credibility of a public administration in the integrity and probity over time.
# eyes of the population it serves.
# LLMs trained on internal databases could serve as
# There can be efficiency gains in using ChatGPT, an institutional memory and simplify knowledge
# such as its capacity to produce first drafts or sum- management. But issues can arise when it comes
# maries of administrative documents. According to reproducing results. Large language models can
# to OpenAI, GPT-4 will offer further improvements produce consistent answers, particularly in the case
# for more complex tasks requiring the handling of of short and relatively simple queries. However, for
# more subtle instructions. However, there are more complex input, they are generally unable to
# still limits to the reliability of the output. Firstly, produce exactly the same answer to the same query
# whilst answers created by ChatGPT usually sound over time. Compared to other language models,
# convincing, the content can be rather superficial. ChatGPT’s abilities to recall input are remarkable.
# The quality of output is also very dependent on But although it is able to remember and include
# the exact wording of the prompt. input of up to 3,000 words in an ongoing conversa-
# tion, it cannot recall previous conversations across
# Secondly, despite efforts to make its technology different threads. When asked by the ART team,
# more reliable, ChatGPT still "hallucinates" on occa- ChatGPT itself indicated that the responses it gene-
# sions and offers inaccurate or misleading informa- rates may vary based on the input, the context of the
# tion. It also tends to provide an answer – any answer, conversation, and the training data (see fig.8).
# rather than admit that it is unable to respond. (Fol-
# lowing the integration by Microsoft of ChatGPT based
# technology in its search engine, Bing once claimed
# that "running was invented in the 1700s by Thomas
# Running"70). OpenAI claims that for GPT-4 it is possible
# to reduce “significantly” the occurrence of hallucina-
# tions. However, unless they can be eliminated com-
# pletely, an improvement could - counterintuitively -
# create an even greater risk for quality of out-
# put given that greater trust may lead to less
# human scrutiny. In the case of ChatGPT, which
# does not provide sources, most claims would
# still need to be manually fact-checked. Some
# more specialised language models already
# provide sources within a limited context71.
# Thirdly, there are no industry-wide established stan-
# dards or benchmarks for the safety and performance
# of LLM, which makes it quite difficult to compare the
# quality of individual models and choose the one best
# adapted for a specific task72. Finally, induced human
# dependence on technology may lead to a loss of
# training and corresponding reduction in the ability
# of humans to perform tasks which can be delegated
# Fig.8: ChatGPT’s reply on a question asked by the ART team
# to machines or even to a decline in the capacity for
# on its capacity to generate consistent answers.
# critical thinking. Without additional (human) quality
# control, all these elements could lead to output of
# lower quality and even basic errors.
# --------------------------------------------------
# page 13
# ⸺ 13
# → Citizens’ involvement and trust they do so with less and less transparency (as refer-
# is the part of the democratic processes allowing red to above, the release of models by OpenAI has
# members of the public to ensure that decisions moved from an open-source and well-documented
# affecting their lives are taken in support of the approach to one which provides little or no basic
# common good. technical information). This raises the question as
# to whether the use of ChatGPT in sensitive areas of
# LLMs can help here. They can be used to perso- public administration genuinely serves the public
# nalize and tailor messages to citizens or MPs, interest, or rather the interests of its parent company
# such as in the context of political campaigns. or owner. Even the creators of LLMs acknowledge the
# This could help organisations or groups of indi- risk that models could be trained to give precedence
# viduals without access to public affairs profes- to a particular viewpoint or over-emphasise a speci-
# sionals to be included in the decision-making fic perspective79. To date, neither the EU nor the US
# process. LLMs could also support citizens who have dedicated legislation in force setting standards
# might be less comfortable with drafting letters to for the deployment of LLMs, nor do they have an
# public administrations or elected officials. agency exercising oversight over the development of
# LLMs80, although the EU is currently looking at how
# However, trust could be undermined if citizens LLMs might be covered within the scope of the future
# feel that AI is largely replacing human agency in AI Act. Without greater transparency and oversight81,
# responding to their queries or in helping shape it is extremely difficult to determine whose
# decisions and policies of their local administra- interests are ultimately being served.
# tion. In addition, ChatGPT could be used to boost
# lobbying activities through the automatic com-
# position of input into regulatory processes such → Data protection and security
# as letters to elected officials, or to generate social refers to the protection of the significant quanti-
# media posts and comments on newspaper web- ties of sensitive or personal information held and
# sites. LLMs could help identify the most relevant managed by public administrations.
# individuals at all levels of government and target
# them with a flood of tailor-made messages73. Given LLMs such as ChatGPT and GPT-4 can be used
# the ability of LLMs to replicate closely human mes- to identify vulnerabilities in computer systems
# sages, they could also be used to support large- and databases, such as mistakes in lines of code,
# scale disinformation campaigns74 and generate but there are some important limitations related
# misleading impressions of public opinion. Current to their tendency to hallucinate and to the size
# technology for determining if a text is written by of source code which needs to be small enough
# an AI such as GTP Zero75 is not sufficiently deve- to fit in the context window create some limita-
# loped to allow for a reliable detection rate. tions. There are also a number of language models
# that can be used to help detect malware, such as
# MalBERT82.
# → Serving public interest:
# Public administrations are committed to provide But there are also risks from LLMs for the pro-
# services in the intrest of their citizens76. tection of data. By hoovering up all information
# on content created while using a ChatGPT-ac-
# Even though large language models appear to be able count in a non-anonymized way and using it to
# to replicate general human morals and values from train future versions, OpenAI can generate access
# their training data77, it is not clear overall whose inte- to a huge quantity of information. This informa-
# rests they prioritise. LLMs require huge investment tion includes queries, answers, IP addresses and
# to finance their development and operation. Only location, that can be disclosed to affiliates and
# a small number of well-funded start-ups and tech will be stored on US-based servers83. Anyone in
# giants have access to this level of funding, with public possession of this data from a public adminis-
# and open-source development lagging behind78. tration could gain insights into internal discus-
# This means that a small number of companies are sions. In their documentation released alongside
# determining the software and models on offer, and GPT-4, OpenAI states that it has been fine-tuned
# --------------------------------------------------
# page 14
# ⸺ 14
# on ‘production traffic (with consent from without users’ consent, it includes a lot of publicly
# users)’. This consent is in practice automatically accessible information of which citizens may be
# granted by anyone signing up for an account to unaware - data that could also have been leaked
# use ChatGPT or other OpenAI models84. or inadvertently shared86. With the right queries,
# adversaries can get LLMs to disclose information
# Secondly, LLMs have been shown to memorise on an individual, such as an elected official or
# their training data, which can then be extracted by indeed any private citizen, without their consent.
# skilled users of the model through relatively simple
# techniques85. A future LLM trained on non-anony- Thirdly, LLMs, with their capacity to generate code
# mised input data from previous models that can be upon request can facilitate access to the deve-
# directly linked to a public administration could in lopment of malware. Even though built-in safe-
# theory be used to access internal information. Fur- guards are supposed to stop ChatGPT from creating
# thermore, as models such as ChatGPT are trained malware, security experts have shown that these
# on data that has been scraped from the internet features can be circumvented87.
# How could the risks posed by LLMs be mitigated?
# If large language models are here to stay, the question The public sector is beginning to look at a mix of mea-
# should be raised as to how public administrations can sures designed to reduce the most significant risks.
# retain the advantages of using these models whilst Most of these measures relate to the models them-
# mitigating their risks. Mitigating the risks that LLMs selves and how they are run, while others concern
# pose means first understanding their nature, poten- regulation and the way the models are used.
# tial, limitations, and their possible impact on the key
# functions of a public administration. It also means
# sharing this information with the public.
# Measures regarding the models
# → Public sector bodies could develop their own computing power, which means that they will have
# models. However, although the cost of developing to be run on cloud servers that can be accessed
# and training large language models seem to have remotely via the internet. This could create pro-
# decreased lately,88 the resources required are still blems with sensitive internal data that needs to stay
# huge. Even with increased energy efficiency, these on site and would also incur costs from an external
# development costs are likely to remain beyond the cloud provider.
# means of most public administrations, not to men-
# tion the need to attract and retain qualified specia- → Models could be run locally. Edge models are
# lists. models that are deliberately small-scale and can
# either be fine-tuned larger models or smaller models
# → Models could be fine-tuned. As the success trained from scratch. They can be run on-site and
# of ChatGPT has shown, a language model does without access to the internet, which greatly impro-
# not need to be excessively large to deliver use- ves costs and privacy, making them more suitable
# ful results. Smaller, more fine-tuned models are for the more limited means of public sector IT sys-
# a possibility, even though their often-proprietary tems. As they do not need to transmit data to a
# nature means that there would still be limited cloud, they can even be faster than internet-connec-
# transparency on their exact architecture and ini- ted models depending on the hardware used to run
# tial training data. Most major general purpose LLM them. Because of their small size, edge models offer
# providers offer smaller versions that can be fine- only a limited functionality89. There is also evidence
# ...
# 48 S ee ‘The Future of Jobs Report 2020’, World Economic Forum, October 2020, https://www3.weforum.org/docs/WEF_Future_of_Jobs_2020.pdf,
# pp. 29-34.
# 49 ‘Generative AI set to affect 300mn jobs across major economies’, Financial Times, 27 March 2023, https://www.ft.com/content/7dec4483-ad34-4007-
# bb3a-7ac925643999.
# 50 B rady and Wang Ting, ‘Chatting about ChatGPT: How May AI and GPT Impact Academia and Libraries?’ Library Hi Tech News, 2023. https://papers.ssrn.
# com/sol3/Delivery.cfm/SSRN_ID4333415_code5653239.pdf?abstractid=4333415&mirid=1&type=2.
# 51 OECD, ‘European Principles for Public Administration ‘, SIGMA Papers, No. 27, OECD Publishing, 1999, https://doi.org/10.1787/5kml60zwdr7h-en ; De Vries,
# Michiel S. and Pan Suk Kim, Value and Virtue in Public Administration A Comparative Perspective, Springer, 2011.
# 52 T ero Erkkilä, ‘Transparency in Public Administration‘, Oxford Research Encyclopedia of Politics, 29 May 2020, https://doi.org/10.1093/
# acrefore/9780190228637.013.1404.
# 53 H annah Bloch-Wehba, ‘Transparency's AI Problem’, Knight First Amendment Institute and Law and Political Economy Project's Data & Democracy Essay
# Series, 2021, https://scholarship.law.tamu.edu/facscholar/1477, pp. 7-12.
# 54 Radford A, Wu J, Child R, Luan D, Amodei D, Sutskever I. ‘Language models are unsupervised multitask learners’. Computer Science, 24 February 2019,
# https://d4mucfpksywv.cloudfront.net/better-language-models/language-models.pdf.
# 55 O penAI’s usage policy prohibits using its models for “High risk government decision-making, including: Law enforcement and criminal justice; Migration
# and asylum”, but this still leaves some scope for a potential use of its models for decision-making processes, see OpenAI usage policies, 17 March 2023,
# https://openai.com/policies/usage-policies.
# 56 Emily M. Bender, Gebru Timnit, Angelina McMillan-Major, and Schmargaret Schmitchell, ‘On the Dangers of Stochastic Parrots: Can Language Models Be
# Too Big?’, in the Association for Computing Machinery Conference on Fairness, Accountability, and Transparency, March 2021,
# https://dl.acm.org/doi/10.1145/3442188.3445922#sec-cit.
# 57 Special Eurobarometer 523: Corruption, March-April 2022, https://europa.eu/eurobarometer/api/deliverable/download/file?deliverableId=83025, p. 16.
# 58 Matthew M. Young, Justin B. Bullock, and Jesse D. Lecy. ‘Artificial discretion as a tool of governance: a framework for understanding the impact of
# artificial intelligence on public administration’, Perspectives on Public Management and Governance 2, no.4, 2019, p. 308.
# 59 Size does not guarantee diversity even when looking at the whole Internet. Internet access is not evenly distributed, resulting in an overrepresentation
# of younger users and those from developed countries. The voices of people most likely to hew to a hegemonic viewpoint are also more likely to be
# retained.
# 60 F ahim Faisal, Yinkai Wang, Antonios Anastasopoulos, ‘Dataset Geography: Mapping Language Data to Language Users’, Proceedings of the 60th Annual
# Meeting of the Association for Computational Linguistics Volume 1: Long Papers, 22-27 May 2022, p. 3384.
# 61 Schramowski, Patrick, Turan, Cigdem, Andersen, Nico, Rothkopf, Constantin A., and Kersting, Kristian, ‘Large Pre-trained Language Models Contain
# Human-like Biases of What is Right and Wrong to Do’, Nature Machine Intelligence, 2103.11790.pdf, p.16 ; Abid, Abubkar, Farooqi, Maheen, and Zou,
# James, ‘Persistent Anti-Muslim Bias in Large Language Models’ AAAI/ACM Conference on AI, Ethics, and Society, 2021, 2101.05783.pdf.
# --------------------------------------------------
# page 22
# ⸺ 22
# 62 Emily Bender et al, ‘On the Dangers of Stochastic Parrots…’, op. cit., pp. 613-615.
# 63 Long Ouyang, Jeff Wu, Xu Jiang, Diogo Almeida, Carroll L. Wainwright, Pamela Mishkin, Chong Zhang, Sandhini Agarwal, Katarina Slama, Alex Ray, John
# Schulman, Jacob Hilton, Fraser Kelton, Luke Miller, Maddie Simens, Amanda Askell, Peter Welinder, Paul Christiano, Jan Leike, and Ryan Lowe, ‘Training
# language models to follow instructions with human feedback’ Thirty-Sixth Conference on Neural Information Processing Systems, 28 November 2022,
# 2203.02155.pdf, pp. 19-20.
# 64 S aar Alon-Barkat and Madalina Busuioc, ‘Human–AI Interactions in Public Sector Decision Making: “Automation Bias” and “Selective Adherence”
# to Algorithmic Advice’, Journal of Public Administration Research and Theory, Volume 33, Issue 1, January 2023, https://academic.oup.com/jpart/
# article/33/1/153/6524536., pp. 165-166.
# 65 Crawford, Kate, Atlas of AI, New Haven: Yale University Press, 2021.
# 66 C hatGPT Burns Millions Every Day. Can Computer Scientists Make AI One Million Times More Efficient?’, Forbes, 10 February 2023 https://www.
# forbes.com/sites/johnkoetsier/2023/02/10/chatgpt-burns-millions-every-day-can-computer-scientists-make-ai-one-million-times-more-
# efficient/?sh=771ef56d6944.
# 67 D avid Patterson, Joseph Gonzalez, Quoc Le, Chen Liang, Lluis-Miquel Munguia, Daniel Rothchild, David So, Maud Texier, and Jeff Dean, ‘Carbon
# Emissions and Large Neural Network Training’, arXiv pre-print, https://arxiv.org/ftp/arxiv/papers/2104/2104.10350.pdf, p. 6.
# 68 R oy Schwartz, Jesse Dodge, Noah A. Smith, and Oren Etzioni, ‘Creating efficiency in AI research will decrease its carbon footprint and increase its
# inclusivity as deep learning study should not require the deepest pockets’ Green AI, https://dl.acm.org/doi/pdf/10.1145/3381831,p. p. 63; David Patterson,
# ‘Reducing the carbon emissions of AI’ - OECD.AI’, 12 April 2022, https://oecd.ai/en/wonk/reducing-ai-Reducing the carbon- emissions of AI - OECD.AI.
# 69 David Patterson, Joseph Gonzalez, Urs Hölzle, Quoc Le, Chen Liang, Lluis-Miquel Munguia, Daniel Rothchild, David So, Maud Texier, and Jeff Dean, ‘The
# Carbon Footprint of Machine Learning Training Will Plateau, Then Shrink‘, IEEE, https://ieeexplore.ieee.org/document/9810097 , pp. 6-7.
# 70 ‘Chatbots Got Big—and Their Ethical Red Flags Got Bigger’, Wired, 16 February 2023, https://www.wired.com/story/chatbots-got-big-and-their-ethical-
# red-flags-got-bigger/.
# 71 See https://consensus.app/home/about-us/
# 72 Deep Ganguli, Danny Hernandez, Liane Lovitt, Nova Dassarma, Tom Henighan, Andy jones, Nicholas Joseph, Jackson Kernion, Ben Mann, Amanda
# Askell, Yuntao Bai, Anna Chen, Tom Conerly, Dawn Drain, Nelson Elhage, Sheer el Showk, Stanislav Fort, Zac Hatfield-Dodds, Scott Johnston, Shauna
# Kravec, Neel Nanda, Kamal Ndousse, Catherine Olsson, Daniela Amodei, Tom Brown, Jared Kaplan, Sam McCandlish, Chris Olah, Ario Amodei, and Jack
# Clark, ‘Predictability and Surprise in Large Generative Models’, 2022, p.11.
# 73 ‘ How ChatGPT Highjacks Democracy’, The New York Times, 15 January 2023 https://www.nytimes.com/2023/01/15/opinion/ai-chatgpt-lobbying-
# democracy.html.
# 74 Ben Buchanan, Andrew Lohn, Micah Musser, and Katerina Sedova ‘Truth, Lies, and Automation - How Language Models Could Change Disinformation’
# Center for Security and Emerging Technology, May 2021.
# 75 ‘GPT Zero Is Designed To Recognize Texts Written By AI’, Medium, 12 January 2023 https://medium.datadriveninvestor.com/gpt-zero-is-designed-to-
# recognize-texts-written-by-ai-ab7ff4d11fd6.
# 76 Elmer B. Staats, ‘Public Service and the Public Interest’, Public Administration Review ublic Administration Review, Vol. 48, No. 2, March-April 1988, pp.
# 601-605+ii.
# 77 Schramowski, Patrick, Turan, Cigdem, Andersen, Nico, Rothkopf, Constantin A., and Kersting, Kristian, ‘Large Pre-trained Language Models Contain
# Human-like Biases of What is Right and Wrong to Do’, Nature Machine Intelligence, p. 17, 2103.11790.pdf, p.11.
# 78 Deep Ganguli et al, ‘Predictability and Surprise in Large Generative Models’, op.cit., p.13.
# 79 Michiel Bakker et al., ‘Fine-tuning language models…’ op.cit., p.10.
# 80 D eep Ganguli et al., ‘Predictability and surprise in large generative models’, 2022 ACM Conference on Fairness, Accountability, and Transparency, p. 9.
# 81 Khari Johnson, ‘The Movement to Hold AI Accountable Gains More Steam’, Wired, 02 December 2021, https://www.wired.com/story/movement-hold-ai-
# accountable-gains-steam/.
# 82 Abir Rahali and Moulay A. Akhloufi, ‘MalBERT: Malware Detection using Bidirectional Encoder Representations from Transformers,’ 2021 IEEE
# International Conference on Systems, Man, and Cybernetics (SMC), Melbourne, Australia, 2021, pp. 3226-3231.
# 83 ‘Privacy policy’, OpenAI, 14 March 2023, https://openai.com/policies/privacy-policy.
# 84 ‘ GPT-4 System Card’, OpenAI, 23 March 2023, https://cdn.openai.com/papers/gpt-4-system-card.pdf, p.22.
# 85 Nicholas Carlini, Florian Tramer, Eric Wallace, Matthew Jagielski, Ariel Herbert-Voss, Katherine Lee, Adam Roberts et al. ‘Extracting Training Data from
# Large Language Models’, USENIX Security Symposium, vol. 6, 11 August 2021, p.13.
# 86 H annah Brown, Katherine Lee, Fatemehsadat Mireshghallah, Reza Shokri, and Florian Tramèr, ‘What Does it Mean for a Language Model to Preserve
# Privacy?’, 2022 ACM Conference on Fairness, Accountability, and Transparency, 20 June 2022, pp. 2288-2289.
# 87 E ran Shimony and Omer Tsarfati, ‘Chatting Our Way Into Creating a Polymorphic Malware’, Cyberark, 17 January 2023, https://www.cyberark.com/
# resources/threat-research-blog/chatting-our-way-into-creating-a-polymorphic-malware.
# 88 O penAI is among the companies who have recently reduced prices to train their models, see ‘September 2022 - OpenAI API Pricing Update FAQ’,
# OpenAI, September 2022, https://help.openai.com/en/articles/6485334-september-2022-openai-api-pricing-update-faq; and Daniel Zhang, Nestor
# Maslej, Erik Brynjolfsson, John Etchemendy, Terah Lyons, James Manyika, Helen Ngo, Juan Carlos Niebles, Michael Sellitto, Ellie Sakhaee, Yoav
# Shoham, Jack Clark, and Raymond Perrault, ‘The AI Index 2022 Annual Report,’ AI Index Steering Committee, Stanford Institute for Human-Centered AI,
# Stanford University, March 2022, p. 97.
# 89 Kyle Wiggers, ‘The emerging types of language models and why they matter’, TechCrunch, 28 April 2022, https://techcrunch.com/2022/04/28/the-
# emerging-types-of-language-models-and-why-they-matter/.
# 90 S ara Hooker, Nyalleng Moorosi, Gregory Clark, Samy Bengio, and Emily Denton, ‘Characterising bias in compressed models’, arXiv preprint
# arXiv:2010.03058, 06 October 2020, https://arxiv.org/pdf/2010.03058.pdf.
# 91 ‘Complete Guide to Edge Computing: Edge IoT, Edge AI, and More’, Run.ai, https://www.run.ai/guides/edge-computing.
# --------------------------------------------------
# page 23
# ⸺ 23
# 92 ‘Joint Recommendation for Language Model Deployment’, Cohere, OpenAI, and AI 21 Labs, https://cdn.openai.com/papers/joint-recommendation-for-
# language-model-deployment.pdf.
# 93 Artificial Intelligence Act: Council calls for promoting safe AI that respects fundamental rights‘, Council of the European Union, 6 December 2022,
# https://www.consilium.europa.eu/en/press/press-releases/2022/12/06/artificial-intelligence-act-council-calls-for-promoting-safe-ai-that-respects-
# fundamental-rights/.
# 94 J ohanna Okerlund, Evan Klasky, Aditya Middha, Sujin Kim, Hannah Rosenfeld, Molly Kleinman, and Shobita Parthasarathy, ‘What’s in the Chatterbox?
# Large Language Models, Why They Matter, and What We Should Do About Them’, University of Michigan Technology Assessment Report, April 2022,
# https://stpp.fordschool.umich.edu/research/research-report/whats-in-the-chatterbox; Jess Whittlestone and Jack Clark, ‘Why and How Governments
# Should Monitor AI Development’, 2021, https://arxiv.org/pdf/2108.12427.pdf.
# 95 Selbst, ‘An Institutional View Of Algorithmic Impact Assessments’, Harvard Journal of Law & Technology 2021; UCLA School of Law, Public Law Research
# Paper No. 21-25, https://ssrn.com/abstract=3867634.
# 96 ‘ IEEE calls for standards to combat climate change and protect kids in the age of AI’, VentureBeat, 6 February 2020, https://venturebeat.com/ai/ieee-
# calls-for-standards-to-combat-climate-change-and-protect-kids-in-the-age-of-ai/.
# 97 Rishi Bommasani, Percy Liang, and Tony Lee, ‘Language Models are Changing AI. We Need to Understand Them’, Standford University Human-Centered
# Artificial Intelligence https://hai.stanford.edu/news/language-models-are-changing-ai-we-need-understand-them.
# 98 H annah Bloch-Wehba, ‘Transparency's AI Problem’, op. cit., pp.19-21.
# 99 ‘ Tech’s hottest new job: AI whisperer. No coding required.’ The Washington Post, 25 February 2023, https://www.washingtonpost.com/
# technology/2023/02/25/prompt-engineers-techs-next-big-job/.
# 100 Zhuo, Terry Yue, Yujin Huang, Chunyang Chen, and Zhenchang Xing., ‘Exploring ai ethics of chatgpt: A diagnostic analysis’, arXiv preprint, 22 February
# 2023, arXiv:2301.12867.
# 101 E mily Bender et al, ‘On the Dangers of Stochastic Parrots…’, op. cit., pp. 614.
# 102 GPT-4 System Card’, OpenAI, 23 March 2023, https://cdn.openai.com/papers/gpt-4-system-card.pdf, p.29.
# 103 Miller, Katherine, ‘How Do We Fix and Update Large Language Models?’, Stanford University Human-Centered Artificial Intelligence, 13 February 2023,
# https://hai.stanford.edu/news/how-do-we-fix-and-update-large-language-models.
# 104 GPT-4 System Card’, OpenAI, 23 March 2023, https://cdn.openai.com/papers/gpt-4-system-card.pdf, p.21.
# 105 Matteo Pagani, ‘Bring the ChatGPT model into our applications’, Microsoft, https://techcommunity.microsoft.com/t5/modern-work-app-consult-blog/
# bring-the-chatgpt-model-into-our-applications/ba-p/3766574.
# 106 Nicole Herskowitz, ‘Microsoft Teams Premium: Cut costs and add AI-powered productivity‘, Microsoft, 1 February 2023 https://www.microsoft.com/
# en-us/microsoft-365/blog/2023/02/01/microsoft-teams-premium-cut-costs-and-add-ai-powered-productivity/.
# 107 ‘ Search wars reignited by artificial intelligence breakthroughs’, Financial Times, 6 February 2023. https://www.ft.com/content/b236b70d-82dc-40f8-
# 84be-dc4daff151e4.
# 108 Sundar Pichai, ‘An important next step on our AI journey’, Google, 6 February 2023 https://blog.google/technology/ai/bard-google-ai-search-updates.
# 109 ‘First AI Art Generator Lawsuits Threaten Future of Emerging Tech’, Bloomberg, 20 January 2023. https://news.bloomberglaw.com/ip-law/first-ai-art-
# generator-lawsuits-threaten-future-of-emerging-tech.
# 110 ‘Lawsuit Takes Aim at the Way A.I. Is Built’, New York Times, 23 November 2022. https://www.nytimes.com/2022/11/23/technology/copilot-microsoft-ai-
# lawsuit.html
# 111 ‘L‘Intelligenza artificiale: il Garante blocca ChatGPT. Raccolta illecita di dati personali. Assenza di sistemi per la verifica dell’età dei minori’, Garante per la
# protezione dei dati personali, 31 March 2023, https://www.gpdp.it/web/guest/home/docweb/-/docweb-display/docweb/9870847.
# 112 ‘Investigation by EU authorities needed into ChatGPT technology’, European Consumer Organisation (BEUC), 30 March 2023, https://www.beuc.eu/
# press-releases/investigation-eu-authorities-needed-chatgpt-technology.
# 113 ‘Pause Giant AI Experiments: An Open Letter’, Future of Life Institute, 22 March 2023, https://futureoflife.org/open-letter/pause-giant-ai-experiments/;
# Jyoti Narayan, Krystal Hu, Martin Coulter, Supantha Mukherjee, ‘Elon Musk and others urge AI pause, citing ‘risks to society’’, Reuters, 29 March 2023,
# https://www.reuters.com/technology/musk-experts-urge-pause-training-ai-systems-that-can-outperform-gpt-4-2023-03-29/.
# 114 ‘The emerging types of language models and why they matter’, TechCrunch, April 28 2023,https://techcrunch.com/2022/04/28/the-emerging-types-of-
# language-models-and-why-they-matter/?guccounter=1.
# 115 ‘Trends in AI — 2023 Round-up’, Medium/ Towards AI, January 25 2023, https://pub.towardsai.net/trends-in-ai-2023-round-up-e6c52578fe92.
# 116 N athan Benaich and Ian Hogarth, ‘State of AI Report 2022’, State of AI, https://www.stateof.ai/.
# Disclaimer: During the writing process, ChatGPT was used to obtain a view on some of the descriptions
# of machine learning techniques and was consulted on whether its own assessment of its ability to respect
# some of the principles underpinning the work of the public sector corresponded with our own.
# --------------------------------------------------

# %%
# %pip install pdf2image
# Out:
# Collecting pdf2image
#   Downloading pdf2image-1.16.3-py3-none-any.whl (11 kB)
# Requirement already satisfied: pillow in /Users/hanseungryun/.local/share/virtualenvs/python_web-R20azaVT/lib/python3.11/site-packages (from pdf2image) (9.5.0)
# Installing collected packages: pdf2image
# Successfully installed pdf2image-1.16.3
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pdfplumber
from docx import Document
from pdf2image import convert_from_path
from PIL import Image

# PDF 파일 열기
with pdfplumber.open("test.pdf") as pdf:
    # Word 문서 생성
    document = Document()

    # 페이지 반복
    for i, page in enumerate(pdf.pages):
        # 텍스트 추출
        text = page.extract_text()

        # 텍스트 추가
        if text:
            paragraph = document.add_paragraph(text)

        # # 이미지 추출
        # images = page.extract_images()
        # for j, image in enumerate(page.images):
        #     # 이미지 파일 생성
        #     image_path = f"image_{i}_{j}.png"
        #     with open(image_path, "wb") as f:
        #         f.write(image["stream"].get_rawdata()) 
        #     # 이미지 추가
        #     paragraph = document.add_paragraph()
        #     run = paragraph.add_run()
        #     run.add_picture(f"image_{i}.png")

    # Word 문서 저장
    document.save("output.docx")
